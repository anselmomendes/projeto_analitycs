# %%
import requests

# %%
url = r'https://sidra.ibge.gov.br/geratabela/DownloadSelecaoComplexa/-934357588'

# %%
import pandas as pd
import numpy as np
data = pd.read_excel(url, skiprows=[0,1,2,3])

# %%
data.head()
# Out:
#                    Unnamed: 0 Total Leite (Mil litros)  \
# 0                      Brasil    ..           33680401
# 1  Alta Floresta D'Oeste (RO)    ..               7012
# 2              Ariquemes (RO)    ..              15350
# 3                 Cabixi (RO)    ..               7274
# 4                 Cacoal (RO)    ..              26102
#
#   Ovos de galinha (Mil dúzias) Ovos de codorna (Mil dúzias)  \
# 0                      3842896                       271624
# 1                          265                            -
# 2                          285                            -
# 3                          128                            -
# 4                          996                            -
#
#   Mel de abelha (Quilogramas) Casulos do bicho-da-seda (Quilogramas)  \
# 0                    39677393                                2855320
# 1                        2702                                      -
# 2                         930                                      -
# 3                         745                                      -
# 4                       10057                                      -
#
#   Lã (Quilogramas) Total.1 Leite (Mil litros).1  ...  \
# 0          9755663      ..             33313230  ...
# 1                -      ..                 9024  ...
# 2                -      ..                14497  ...
# 3                -      ..                 8311  ...
# 4                -      ..                21814  ...
#
#   Mel de abelha (Quilogramas).3 Casulos do bicho-da-seda (Quilogramas).3  \
# 0                      45801255                                  3046553
# 1                          2800                                        -
# 2                          1210                                        -
# 3                           640                                        -
# 4                          9000                                        -
#
#   Lã (Quilogramas).3 Total.4 Leite (Mil litros).4  \
# 0            8378597      ..             35445059
# 1                  -      ..                 7258
# 2                  -      ..                16374
# 3                  -      ..                 6259
# 4                  -      ..                18668
#
#   Ovos de galinha (Mil dúzias).4 Ovos de codorna (Mil dúzias).4  \
# 0                        4767338                         295904
# 1                            298                              -
# 2                            279                              -
# 3                            120                              -
# 4                           3813                              -
#
#   Mel de abelha (Quilogramas).4 Casulos do bicho-da-seda (Quilogramas).4  \
# 0                      51507862                                  2742372
# 1                          2849                                        -
# 2                          1251                                        -
# 3                           608                                        -
# 4                          9299                                        -
#
#   Lã (Quilogramas).4
# 0            7978317
# 1                  -
# 2                  -
# 3                  -
# 4                  -
#
# [5 rows x 36 columns]

# %%
end = data[data['Unnamed: 0'] == 'Fonte: IBGE - Pesquisa da Pecuária Municipal'].index[0]

# %%
df = data.iloc[:end]

# %%
df.head()
# Out:
#                    Unnamed: 0 Total Leite (Mil litros)  \
# 0                      Brasil    ..           33680401
# 1  Alta Floresta D'Oeste (RO)    ..               7012
# 2              Ariquemes (RO)    ..              15350
# 3                 Cabixi (RO)    ..               7274
# 4                 Cacoal (RO)    ..              26102
#
#   Ovos de galinha (Mil dúzias) Ovos de codorna (Mil dúzias)  \
# 0                      3842896                       271624
# 1                          265                            -
# 2                          285                            -
# 3                          128                            -
# 4                          996                            -
#
#   Mel de abelha (Quilogramas) Casulos do bicho-da-seda (Quilogramas)  \
# 0                    39677393                                2855320
# 1                        2702                                      -
# 2                         930                                      -
# 3                         745                                      -
# 4                       10057                                      -
#
#   Lã (Quilogramas) Total.1 Leite (Mil litros).1  ...  \
# 0          9755663      ..             33313230  ...
# 1                -      ..                 9024  ...
# 2                -      ..                14497  ...
# 3                -      ..                 8311  ...
# 4                -      ..                21814  ...
#
#   Mel de abelha (Quilogramas).3 Casulos do bicho-da-seda (Quilogramas).3  \
# 0                      45801255                                  3046553
# 1                          2800                                        -
# 2                          1210                                        -
# 3                           640                                        -
# 4                          9000                                        -
#
#   Lã (Quilogramas).3 Total.4 Leite (Mil litros).4  \
# 0            8378597      ..             35445059
# 1                  -      ..                 7258
# 2                  -      ..                16374
# 3                  -      ..                 6259
# 4                  -      ..                18668
#
#   Ovos de galinha (Mil dúzias).4 Ovos de codorna (Mil dúzias).4  \
# 0                        4767338                         295904
# 1                            298                              -
# 2                            279                              -
# 3                            120                              -
# 4                           3813                              -
#
#   Mel de abelha (Quilogramas).4 Casulos do bicho-da-seda (Quilogramas).4  \
# 0                      51507862                                  2742372
# 1                          2849                                        -
# 2                          1251                                        -
# 3                           608                                        -
# 4                          9299                                        -
#
#   Lã (Quilogramas).4
# 0            7978317
# 1                  -
# 2                  -
# 3                  -
# 4                  -
#
# [5 rows x 36 columns]
